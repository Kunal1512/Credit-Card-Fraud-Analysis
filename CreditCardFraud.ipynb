# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/analytics_projects/CreditCardFraud_Project/creditcard.csv')
df.shape
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (284807, 31)

# %%
print(df['Class'].dtype)
# Out:
# int64

# %%
print(df.dtypes)
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
print(df['Class'].value_counts())
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
print(df['Class'].value_counts(normalize=True).round(4))
# Out:
# Class
# 0    0.9983
# 1    0.0017
# Name: proportion, dtype: float64

# %%
print(df.groupby("Class")["Amount"].describe().round(2))
# Out:
#           count    mean     std  min   25%    50%     75%       max
# Class
# 0      284315.0   88.29  250.11  0.0  5.65  22.00   77.05  25691.16
# 1         492.0  122.21  256.68  0.0  1.00   9.25  105.89   2125.87
