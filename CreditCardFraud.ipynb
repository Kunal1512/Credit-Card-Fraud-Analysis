# %%
import pandas as pd
df = pd.read_csv("C:/Users/gupta/OneDrive/Documents/GitHub/Credit-Card-Fraud-Analysis/creditcard.csv")
df.shape
# Out:
# (284807, 31)

# %%
print(df['Class'].dtype)
# Out:
# int64

# %%
print(df.dtypes)
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
print(df['Class'].value_counts())
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
print(df['Class'].value_counts(normalize=True).round(4))
# Out:
# Class
# 0    0.9983
# 1    0.0017
# Name: proportion, dtype: float64

# %%
print(df.groupby("Class")["Amount"].describe().round(2))
# Out:
#           count    mean     std  min   25%    50%     75%       max
# Class
# 0      284315.0   88.29  250.11  0.0  5.65  22.00   77.05  25691.16
# 1         492.0  122.21  256.68  0.0  1.00   9.25  105.89   2125.87

# %%
df["Hour"] = (df["Time"] / 3600).astype(int) % 24
df["Hour"]
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 284802    23
# 284803    23
# 284804    23
# 284805    23
# 284806    23
# Name: Hour, Length: 284807, dtype: int64

# %%
print(df.groupby(["Hour","Class"])["Class"].count().unstack().fillna(0))
# Out:
# Class      0   1
# Hour
# 0       7689   6
# 1       4210  10
# 2       3271  57
# 3       3475  17
# 4       2186  23
# 5       2979  11
# 6       4092   9
# 7       7220  23
# 8      10267   9
# 9      15822  16
# 10     16590   8
# 11     16803  53
# 12     15403  17
# 13     15348  17
# 14     16547  23
# 15     16435  26
# 16     16431  22
# 17     16137  29
# 18     17006  33
# 19     15630  19
# 20     16738  18
# 21     17687  16
# 22     15432   9
# 23     10917  21
